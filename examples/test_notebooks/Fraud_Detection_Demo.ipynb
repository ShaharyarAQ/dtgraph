# %%
import sys
import os

# Go to project root
project_root = os.path.abspath(os.path.join(os.getcwd(), ".."))

# Add dtgraph folder to path
sys.path.append(os.path.join(project_root, "../dtgraph"))

# %%
from dtgraph import Neo4jGraph, Rule, Transformation

hostname = "localhost"
password = "internship"
uri = f"bolt://{hostname}:7687"

graph = Neo4jGraph(uri, database="neo4j", username="neo4j", password=password)

# %%
from type_checking.environment import Environment

env = Environment("../../dtgraph/type_checking/ENVs/env_fraud.json")

# %%
from pg_schema.loader import SchemaLoader

schema = SchemaLoader("../../dtgraph/pg_schema/schemas/schema_fraud_target.json")

# %% [markdown]
# ##### Rules

# %%
Rule1 = Rule(
    """
MATCH (c:Client)
WHERE NOT c:Mule
OPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)
OPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)
OPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)
WITH 
    c,
    collect(DISTINCT e.email) AS emails,
    collect(DISTINCT p.phoneNumber) AS phones,
    collect(DISTINCT s.ssn) AS ssns
LIMIT 3000
GENERATE
(p = (c.id):Person {
    id = c.id,
    name = c.name,
    name_camel_case = apoc.text.upperCamelCase(c.name),
    email = head(emails),
    phone = head(phones),
    ssn = head(ssns)
})
""",
    env=env,
    type_strict=False,
)

Rule2 = Rule(
    """
MATCH (c:Client:Mule)
OPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)
OPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)
OPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)
WITH 
    c,
    collect(DISTINCT e.email) AS emails,
    collect(DISTINCT p.phoneNumber) AS phones,
    collect(DISTINCT s.ssn) AS ssns
LIMIT 3000
GENERATE
(p = (c.id):Person,Scammer {
    id = c.id,
    name = c.name,
    name_camel_case = apoc.text.upperCamelCase(c.name),
    email = head(emails),
    phone = head(phones),
    ssn = head(ssns)
})
""",
    env=env,
    type_strict=False,
)

Rule3 = Rule(
"""
MATCH (c:Client)-[:PERFORMED]->(t:CashIn)
WITH c, collect(t.amount) AS amounts
GENERATE
(p = (c.id):Person {
    id = c.id,
    name = c.name
})
-[():AGGREGATED_CASHIN]->(
    agg = (c.id, "cashin"):CashInSummary {
        all_amounts = amounts,
        count = size(amounts)
    }
)
""",
env=env,
type_strict=False,
)

Rule4 = Rule(
"""
MATCH (c:Client)-[:PERFORMED]->(t:CashOut)
WITH c, collect(t.amount) AS amounts
GENERATE
(p = (c.id):Person {
    id = c.id,
    name = c.name
})
-[():AGGREGATED_CASHOUT]->(
    agg = (c.id, "cashout"):CashOutSummary {
        all_amounts = amounts,
        count = size(amounts)
    }
)
""",
env=env,
type_strict=False,
)

Rule5 = Rule(
"""
MATCH (c:Client)-[:PERFORMED]->(t:Transfer)
WITH c, collect(t.amount) AS amounts
GENERATE
(p = (c.id):Person {
    id = c.id,
    name = c.name
})
-[():AGGREGATED_TRANSFER]->(
    agg = (c.id, "transfer"):TransferSummary {
        all_amounts = amounts,
        count = size(amounts)
    }
)
""",
env=env,
type_strict=False,
)

Rule6 = Rule(
"""
MATCH (c:Client)-[:PERFORMED]->(t:Payment)
WITH c, collect(t.amount) AS amounts
GENERATE
(p = (c.id):Person {
    id = c.id,
    name = c.name
})
-[():AGGREGATED_PAYMENT]->(
    agg = (c.id, "payment"):PaymentSummary {
        all_amounts = amounts,
        count = size(amounts)
    }
)
""",
env=env,
type_strict=False,
)

Rule7 = Rule(
"""
MATCH (c:Client)-[:PERFORMED]->(t:Debit)
WITH c, collect(t.amount) AS amounts
GENERATE
(p = (c.id):Person {
    id = c.id,
    name = c.name
})
-[():AGGREGATED_DEBIT]->(
    agg = (c.id, "debit"):DebitSummary {
        all_amounts = amounts,
        count = size(amounts)
    }
)
""",
env=env,
type_strict=False,
)

Rule8 = Rule(
"""
MATCH (c:Client)-[:PERFORMED]->(t1:Transaction)-[:NEXT]->(t2:Transaction)
OPTIONAL MATCH (t2)-[:TO]->(target)
WITH c, t1, t2, target LIMIT 3000
GENERATE
(f = (c.id, t1.id, t2.id):TransactionFlow {
    from_amount = t1.amount,
    to_amount = t2.amount,
    increasing = t2.amount > t1.amount
})
-[():STARTED_BY]-> (p = (c.id):),
(f)-[():FROM_TX]-> (tx1 = (t1.id):NewTransaction {
    id = t1.id,
    amount = t1.amount
}),
(f)-[():TO_TX]-> (tx2 = (t2.id):NewTransaction {
    id = t2.id,
    amount = t2.amount
}),
(f)-[():TARGET]-> (dest = (target.id):Destination)
""",
env=env,
type_strict=False,
)

# %% [markdown]
# ##### Schema Conformance

# %%
from dtgraph.pg_schema.check_schema import check_schema

check_schema(
    [
        Rule1,
        Rule2,
        Rule3,
        Rule4,
        Rule5,
        Rule6,
        Rule7,
        Rule8
    ],
    schema,
)
# Out:
# --- Checking Rule ---
# Source dictionary:
# {'lhs': 'MATCH (c:Client)\nWHERE NOT c:Mule\nOPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)\nOPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)\nOPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)\nWITH \n    c,\n    collect(DISTINCT e.email) AS emails,\n    collect(DISTINCT p.phoneNumber) AS phones,\n    collect(DISTINCT s.ssn) AS ssns\nLIMIT 3000', 'constructors': [{'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name'}, {'key': 'name_camel_case', 'value': 'apoc.text.upperCamelCase(c.name)'}, {'key': 'email', 'value': 'head(emails)'}, {'key': 'phone', 'value': 'head(phones)'}, {'key': 'ssn', 'value': 'head(ssns)\n'}]}]}
#
# --- Checking Rule ---
# Source dictionary:
# {'lhs': 'MATCH (c:Client:Mule)\nOPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)\nOPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)\nOPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)\nWITH \n    c,\n    collect(DISTINCT e.email) AS emails,\n    collect(DISTINCT p.phoneNumber) AS phones,\n    collect(DISTINCT s.ssn) AS ssns\nLIMIT 3000', 'constructors': [{'alias': 'p', 'ids': ['c.id'], 'labels': ['Person', 'Scammer'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name'}, {'key': 'name_camel_case', 'value': 'apoc.text.upperCamelCase(c.name)'}, {'key': 'email', 'value': 'head(emails)'}, {'key': 'phone', 'value': 'head(phones)'}, {'key': 'ssn', 'value': 'head(ssns)\n'}]}]}
#
# --- Checking Rule ---
# Source dictionary:
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:CashIn)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_CASHIN']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"cashin"'], 'labels': ['CashInSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# --- Checking Rule ---
# Source dictionary:
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:CashOut)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_CASHOUT']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"cashout"'], 'labels': ['CashOutSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# --- Checking Rule ---
# Source dictionary:
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:Transfer)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_TRANSFER']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"transfer"'], 'labels': ['TransferSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# --- Checking Rule ---
# Source dictionary:
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:Payment)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_PAYMENT']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"payment"'], 'labels': ['PaymentSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# --- Checking Rule ---
# Source dictionary:
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:Debit)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_DEBIT']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"debit"'], 'labels': ['DebitSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# --- Checking Rule ---
# Source dictionary:
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t1:Transaction)-[:NEXT]->(t2:Transaction)\nOPTIONAL MATCH (t2)-[:TO]->(target)\nWITH c, t1, t2, target LIMIT 3000', 'constructors': [{'src': {'alias': 'f', 'ids': ['c.id', 't1.id', 't2.id'], 'labels': ['TransactionFlow'], 'properties': [{'key': 'from_amount', 'value': 't1.amount'}, {'key': 'to_amount', 'value': 't2.amount'}, {'key': 'increasing', 'value': 't2.amount > t1.amount\n'}]}, 'edge': {'ids': [], 'labels': ['STARTED_BY']}, 'tgt': {'alias': 'p', 'ids': ['c.id']}}, {'src': {'alias': 'f'}, 'edge': {'ids': [], 'labels': ['FROM_TX']}, 'tgt': {'alias': 'tx1', 'ids': ['t1.id'], 'labels': ['NewTransaction'], 'properties': [{'key': 'id', 'value': 't1.id'}, {'key': 'amount', 'value': 't1.amount\n'}]}}, {'src': {'alias': 'f'}, 'edge': {'ids': [], 'labels': ['TO_TX']}, 'tgt': {'alias': 'tx2', 'ids': ['t2.id'], 'labels': ['NewTransaction'], 'properties': [{'key': 'id', 'value': 't2.id'}, {'key': 'amount', 'value': 't2.amount\n'}]}}, {'src': {'alias': 'f'}, 'edge': {'ids': [], 'labels': ['TARGET']}, 'tgt': {'alias': 'dest', 'ids': ['target.id'], 'labels': ['Destination']}}]}
#
# All rules conform to provided schema

# %% [markdown]
# ##### Type Checking

# %%
# Type checking

from dtgraph.type_checking.check_types import check_types

check_types(
    [
        Rule1,
        Rule2,
        Rule3,
        Rule4,
        Rule5,
        Rule6,
        Rule7,
        Rule8
    ],
    env,
)
# Out:
# --- Checking Rule ---
# {'lhs': 'MATCH (c:Client)\nWHERE NOT c:Mule\nOPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)\nOPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)\nOPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)\nWITH \n    c,\n    collect(DISTINCT e.email) AS emails,\n    collect(DISTINCT p.phoneNumber) AS phones,\n    collect(DISTINCT s.ssn) AS ssns\nLIMIT 3000', 'constructors': [{'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name'}, {'key': 'name_camel_case', 'value': 'apoc.text.upperCamelCase(c.name)'}, {'key': 'email', 'value': 'head(emails)'}, {'key': 'phone', 'value': 'head(phones)'}, {'key': 'ssn', 'value': 'head(ssns)\n'}]}]}
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: id
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: name
# AST:
# FunctionCall: apoc.text.upperCamelCase
#     └── PropertyAccess
#         ├── var: c
#         └── prop: name
# AST:
# FunctionCall: head
#     └── Variable
#         └── name: emails
# AST:
# FunctionCall: head
#     └── Variable
#         └── name: phones
# AST:
# FunctionCall: head
#     └── Variable
#         └── name: ssns
#
# --- Checking Rule ---
# {'lhs': 'MATCH (c:Client:Mule)\nOPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)\nOPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)\nOPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)\nWITH \n    c,\n    collect(DISTINCT e.email) AS emails,\n    collect(DISTINCT p.phoneNumber) AS phones,\n    collect(DISTINCT s.ssn) AS ssns\nLIMIT 3000', 'constructors': [{'alias': 'p', 'ids': ['c.id'], 'labels': ['Person', 'Scammer'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name'}, {'key': 'name_camel_case', 'value': 'apoc.text.upperCamelCase(c.name)'}, {'key': 'email', 'value': 'head(emails)'}, {'key': 'phone', 'value': 'head(phones)'}, {'key': 'ssn', 'value': 'head(ssns)\n'}]}]}
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: id
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: name
# AST:
# FunctionCall: apoc.text.upperCamelCase
#     └── PropertyAccess
#         ├── var: c
#         └── prop: name
# AST:
# FunctionCall: head
#     └── Variable
#         └── name: emails
# AST:
# FunctionCall: head
#     └── Variable
#         └── name: phones
# AST:
# FunctionCall: head
#     └── Variable
#         └── name: ssns
#
# --- Checking Rule ---
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:CashIn)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_CASHIN']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"cashin"'], 'labels': ['CashInSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: id
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: name
# AST:
# Variable
#     └── name: amounts
# AST:
# FunctionCall: size
#     └── Variable
#         └── name: amounts
#
# --- Checking Rule ---
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:CashOut)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_CASHOUT']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"cashout"'], 'labels': ['CashOutSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: id
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: name
# AST:
# Variable
#     └── name: amounts
# AST:
# FunctionCall: size
#     └── Variable
#         └── name: amounts
#
# --- Checking Rule ---
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:Transfer)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_TRANSFER']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"transfer"'], 'labels': ['TransferSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: id
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: name
# AST:
# Variable
#     └── name: amounts
# AST:
# FunctionCall: size
#     └── Variable
#         └── name: amounts
#
# --- Checking Rule ---
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:Payment)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_PAYMENT']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"payment"'], 'labels': ['PaymentSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: id
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: name
# AST:
# Variable
#     └── name: amounts
# AST:
# FunctionCall: size
#     └── Variable
#         └── name: amounts
#
# --- Checking Rule ---
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:Debit)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_DEBIT']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"debit"'], 'labels': ['DebitSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: id
# AST:
# PropertyAccess
#     ├── var: c
#     └── prop: name
# AST:
# Variable
#     └── name: amounts
# AST:
# FunctionCall: size
#     └── Variable
#         └── name: amounts
#
# --- Checking Rule ---
# {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t1:Transaction)-[:NEXT]->(t2:Transaction)\nOPTIONAL MATCH (t2)-[:TO]->(target)\nWITH c, t1, t2, target LIMIT 3000', 'constructors': [{'src': {'alias': 'f', 'ids': ['c.id', 't1.id', 't2.id'], 'labels': ['TransactionFlow'], 'properties': [{'key': 'from_amount', 'value': 't1.amount'}, {'key': 'to_amount', 'value': 't2.amount'}, {'key': 'increasing', 'value': 't2.amount > t1.amount\n'}]}, 'edge': {'ids': [], 'labels': ['STARTED_BY']}, 'tgt': {'alias': 'p', 'ids': ['c.id']}}, {'src': {'alias': 'f'}, 'edge': {'ids': [], 'labels': ['FROM_TX']}, 'tgt': {'alias': 'tx1', 'ids': ['t1.id'], 'labels': ['NewTransaction'], 'properties': [{'key': 'id', 'value': 't1.id'}, {'key': 'amount', 'value': 't1.amount\n'}]}}, {'src': {'alias': 'f'}, 'edge': {'ids': [], 'labels': ['TO_TX']}, 'tgt': {'alias': 'tx2', 'ids': ['t2.id'], 'labels': ['NewTransaction'], 'properties': [{'key': 'id', 'value': 't2.id'}, {'key': 'amount', 'value': 't2.amount\n'}]}}, {'src': {'alias': 'f'}, 'edge': {'ids': [], 'labels': ['TARGET']}, 'tgt': {'alias': 'dest', 'ids': ['target.id'], 'labels': ['Destination']}}]}
# AST:
# PropertyAccess
#     ├── var: t1
#     └── prop: amount
# AST:
# PropertyAccess
#     ├── var: t2
#     └── prop: amount
# AST:
# ComparisonExpression: >
#     └── PropertyAccess
#         ├── var: t2
#         └── prop: amount
#     └── PropertyAccess
#         ├── var: t1
#         └── prop: amount
# AST:
# PropertyAccess
#     ├── var: t1
#     └── prop: id
# AST:
# PropertyAccess
#     ├── var: t1
#     └── prop: amount
# AST:
# PropertyAccess
#     ├── var: t2
#     └── prop: id
# AST:
# PropertyAccess
#     ├── var: t2
#     └── prop: amount
#
#  All rules passed type checking

# %% [markdown]
# ##### Applying Rules

# %%
my_transform = Transformation(
    [
        Rule1,
        Rule2,
        Rule3,
        Rule4,
        Rule5,
        Rule6,
        Rule7,
        Rule8
    ]
)
my_transform.apply_on(graph)
# Out:
# Index: Added 1 index, completed after 19 ms.
#
# self._dict:  {'lhs': 'MATCH (c:Client)\nWHERE NOT c:Mule\nOPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)\nOPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)\nOPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)\nWITH \n    c,\n    collect(DISTINCT e.email) AS emails,\n    collect(DISTINCT p.phoneNumber) AS phones,\n    collect(DISTINCT s.ssn) AS ssns\nLIMIT 3000', 'constructors': [{'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name'}, {'key': 'name_camel_case', 'value': 'apoc.text.upperCamelCase(c.name)'}, {'key': 'email', 'value': 'head(emails)'}, {'key': 'phone', 'value': 'head(phones)'}, {'key': 'ssn', 'value': 'head(ssns)\n'}]}]}
#
# Before LHS Validation:
#  MATCH (c:Client)
# WHERE NOT c:Mule
# OPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)
# OPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)
# OPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)
# WITH
#     c,
#     collect(DISTINCT e.email) AS emails,
#     collect(DISTINCT p.phoneNumber) AS phones,
#     collect(DISTINCT s.ssn) AS ssns
# LIMIT 3000
#
# props: {('c', 'id'), ('c', 'name')}
#
# After LHS Validation:
#  MATCH (c:Client)
# OPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)
# OPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)
# OPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)
# WHERE NOT c:Mule AND c.id IS NOT NULL AND c.name IS NOT NULL
# WITH c,
#     collect(DISTINCT e.email) AS emails,
#     collect(DISTINCT p.phoneNumber) AS phones,
#     collect(DISTINCT s.ssn) AS ssns
# LIMIT 3000
#
# Rule: Added 4866 labels, created 2433 nodes, set 17031 properties, created 0 relationships, completed after 635 ms.
#
# self._dict:  {'lhs': 'MATCH (c:Client:Mule)\nOPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)\nOPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)\nOPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)\nWITH \n    c,\n    collect(DISTINCT e.email) AS emails,\n    collect(DISTINCT p.phoneNumber) AS phones,\n    collect(DISTINCT s.ssn) AS ssns\nLIMIT 3000', 'constructors': [{'alias': 'p', 'ids': ['c.id'], 'labels': ['Person', 'Scammer'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name'}, {'key': 'name_camel_case', 'value': 'apoc.text.upperCamelCase(c.name)'}, {'key': 'email', 'value': 'head(emails)'}, {'key': 'phone', 'value': 'head(phones)'}, {'key': 'ssn', 'value': 'head(ssns)\n'}]}]}
#
# Before LHS Validation:
#  MATCH (c:Client:Mule)
# OPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)
# OPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)
# OPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)
# WITH
#     c,
#     collect(DISTINCT e.email) AS emails,
#     collect(DISTINCT p.phoneNumber) AS phones,
#     collect(DISTINCT s.ssn) AS ssns
# LIMIT 3000
#
# props: {('c', 'id'), ('c', 'name')}
#
# After LHS Validation:
#  MATCH (c:Client:Mule)
# OPTIONAL MATCH (c)-[:HAS_EMAIL]->(e:Email)
# OPTIONAL MATCH (c)-[:HAS_PHONE]->(p:Phone)
# OPTIONAL MATCH (c)-[:HAS_SSN]->(s:SSN)
# WHERE c.id IS NOT NULL AND c.name IS NOT NULL
# WITH c,
#     collect(DISTINCT e.email) AS emails,
#     collect(DISTINCT p.phoneNumber) AS phones,
#     collect(DISTINCT s.ssn) AS ssns
# LIMIT 3000
#
# Rule: Added 433 labels, created 0 nodes, set 2598 properties, created 0 relationships, completed after 293 ms.
#
# self._dict:  {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:CashIn)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_CASHIN']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"cashin"'], 'labels': ['CashInSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# Before LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:CashIn)
# WITH c, collect(t.amount) AS amounts
#
# props: {('c', 'id'), ('c', 'name')}
#
# After LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:CashIn)
# WHERE c.id IS NOT NULL AND c.name IS NOT NULL
# WITH c, collect(t.amount) AS amounts
#
# Rule: Added 3958 labels, created 1979 nodes, set 11874 properties, created 1979 relationships, completed after 959 ms.
#
# self._dict:  {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:CashOut)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_CASHOUT']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"cashout"'], 'labels': ['CashOutSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# Before LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:CashOut)
# WITH c, collect(t.amount) AS amounts
#
# props: {('c', 'id'), ('c', 'name')}
#
# After LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:CashOut)
# WHERE c.id IS NOT NULL AND c.name IS NOT NULL
# WITH c, collect(t.amount) AS amounts
#
# Rule: Added 3884 labels, created 1942 nodes, set 11652 properties, created 1942 relationships, completed after 589 ms.
#
# self._dict:  {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:Transfer)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_TRANSFER']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"transfer"'], 'labels': ['TransferSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# Before LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:Transfer)
# WITH c, collect(t.amount) AS amounts
#
# props: {('c', 'id'), ('c', 'name')}
#
# After LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:Transfer)
# WHERE c.id IS NOT NULL AND c.name IS NOT NULL
# WITH c, collect(t.amount) AS amounts
#
# Rule: Added 4360 labels, created 2180 nodes, set 13080 properties, created 2180 relationships, completed after 415 ms.
#
# self._dict:  {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:Payment)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_PAYMENT']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"payment"'], 'labels': ['PaymentSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# Before LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:Payment)
# WITH c, collect(t.amount) AS amounts
#
# props: {('c', 'id'), ('c', 'name')}
#
# After LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:Payment)
# WHERE c.id IS NOT NULL AND c.name IS NOT NULL
# WITH c, collect(t.amount) AS amounts
#
# Rule: Added 3892 labels, created 1946 nodes, set 11676 properties, created 1946 relationships, completed after 649 ms.
#
# self._dict:  {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t:Debit)\nWITH c, collect(t.amount) AS amounts', 'constructors': [{'src': {'alias': 'p', 'ids': ['c.id'], 'labels': ['Person'], 'properties': [{'key': 'id', 'value': 'c.id'}, {'key': 'name', 'value': 'c.name\n'}]}, 'edge': {'ids': [], 'labels': ['AGGREGATED_DEBIT']}, 'tgt': {'alias': 'agg', 'ids': ['c.id', '"debit"'], 'labels': ['DebitSummary'], 'properties': [{'key': 'all_amounts', 'value': 'amounts'}, {'key': 'count', 'value': 'size(amounts)\n    '}]}}]}
#
# Before LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:Debit)
# WITH c, collect(t.amount) AS amounts
#
# props: {('c', 'id'), ('c', 'name')}
#
# After LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t:Debit)
# WHERE c.id IS NOT NULL AND c.name IS NOT NULL
# WITH c, collect(t.amount) AS amounts
#
# Rule: Added 2678 labels, created 1339 nodes, set 8034 properties, created 1339 relationships, completed after 351 ms.
#
# self._dict:  {'lhs': 'MATCH (c:Client)-[:PERFORMED]->(t1:Transaction)-[:NEXT]->(t2:Transaction)\nOPTIONAL MATCH (t2)-[:TO]->(target)\nWITH c, t1, t2, target LIMIT 3000', 'constructors': [{'src': {'alias': 'f', 'ids': ['c.id', 't1.id', 't2.id'], 'labels': ['TransactionFlow'], 'properties': [{'key': 'from_amount', 'value': 't1.amount'}, {'key': 'to_amount', 'value': 't2.amount'}, {'key': 'increasing', 'value': 't2.amount > t1.amount\n'}]}, 'edge': {'ids': [], 'labels': ['STARTED_BY']}, 'tgt': {'alias': 'p', 'ids': ['c.id']}}, {'src': {'alias': 'f'}, 'edge': {'ids': [], 'labels': ['FROM_TX']}, 'tgt': {'alias': 'tx1', 'ids': ['t1.id'], 'labels': ['NewTransaction'], 'properties': [{'key': 'id', 'value': 't1.id'}, {'key': 'amount', 'value': 't1.amount\n'}]}}, {'src': {'alias': 'f'}, 'edge': {'ids': [], 'labels': ['TO_TX']}, 'tgt': {'alias': 'tx2', 'ids': ['t2.id'], 'labels': ['NewTransaction'], 'properties': [{'key': 'id', 'value': 't2.id'}, {'key': 'amount', 'value': 't2.amount\n'}]}}, {'src': {'alias': 'f'}, 'edge': {'ids': [], 'labels': ['TARGET']}, 'tgt': {'alias': 'dest', 'ids': ['target.id'], 'labels': ['Destination']}}]}
#
# Before LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t1:Transaction)-[:NEXT]->(t2:Transaction)
# OPTIONAL MATCH (t2)-[:TO]->(target)
# WITH c, t1, t2, target LIMIT 3000
#
# props: {('t1', 'amount'), ('t2', 'amount'), ('t1', 'id'), ('t2', 'id')}
#
# After LHS Validation:
#  MATCH (c:Client)-[:PERFORMED]->(t1:Transaction)-[:NEXT]->(t2:Transaction)
# OPTIONAL MATCH (t2)-[:TO]->(target)
# WHERE t1.amount IS NOT NULL AND t1.id IS NOT NULL AND t2.amount IS NOT NULL AND t2.id IS NOT NULL
# WITH c, t1, t2, target
# LIMIT 3000
#
# Rule: Added 12874 labels, created 6359 nodes, set 39359 properties, created 12000 relationships, completed after 1241 ms.
# 5132

# %% [markdown]
# ##### Abort Transformation

# %%
my_transform.abort()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[21], line 1
# ----> 1 my_transform.abort()
#
# NameError: name 'my_transform' is not defined
